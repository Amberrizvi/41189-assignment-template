# %% [markdown]
#  **41189 Modelling Assignment — Group 8**
#
#  Topic: The impact of COVID-19 on gender inequality and women.
#
#  Group members:
#
#  - Amber Rizvi
#  - Shaanza Bhatti
#  - Vanisri Kannan
#  - Jimmy Wilkinson

# %% [markdown]
# # 1. Introduction

# %% [markdown]
# ## 1.1 State the problem, why it is important/relevant to you and/or more broadly to society

# %% [markdown]
# While COVID-19 has directly and indirectly impacted a wide range of individuals, there has been a disproportionate negative effect on women and gender inequality in Australia due to the government, industry and societal response the pandemic has warranted. This issue is significant as it has the potential to stall and regress progressions made by women in the workplace, the domestic sphere and the political environment. Specifically, the pandemic exasperates the heightened consequences women face due to their over-representation in the healthcare system, financial instability in sectors where they have a larger proportion of employment, increased domestic responsibilities and greater risk of violence and abuse against women (Madgavkar et al, 2020). In addition to these personal implications, the issue is relevant to wider society due to the monetary impacts of a smaller and less diverse workforce created as a result of disruptions to women’s employment (WGEA, 2020).

# %% [markdown]
# # 2. Context, background information, justification

# %% [markdown]
# ## 2.1 Research and review literature, news, digital media, drivers and how the problem is being addressed by academia, industry, government, etc.

# %% [markdown]
# Upon researching, it is evident the problem of increased inequity due to COVID-19 lie overwhelmingly in the categories of employment, domestic responsibilities and violence against women.

# %% [markdown]
# ![image.png](attachment:5b74cdb5-49bb-4e6b-813b-ad844cff7087.png)

# %% [markdown]
# **Figure 2.1.1**

# %% [markdown]
# Figure 2.1.1 summarises how the employment of women in Australia has had a direct effect on gender inequality following COVID-19.
# - Firstly, a significant amount of front-line workers, specifically 75% of health professionals and 88% of midwifery and nursing professionals are women (WGEA, 2020). This has placed a disproportionately large amount of risk of contracting the virus and as a result increased stress due to the pressure on this industry.
# - In addition, sectors with the largest reduction in payrolls from March to April, accommodation and food services, and the second largest, being arts and recreation, both employ significantly more women than men (Crabb, 2020).
# - The slightly larger proportion of women in casual employment translates to a larger likelihood of more women losing jobs or decreasing their hours worked.
# - Of the industries with the greatest reductions in payrolls, as mentioned prior, majority of their short term ( <12 months) casual workers are women (Cassells & Duncan, 2020). As the ‘JobKeeper’ package initially encompassed those employed for 12 months from March 1st 2020 (Australian Taxation Office, 2020), some of those hardest hit from the exclusion parameters have been and will continue to be women.
# - The childcare sector lost access to ‘JobKeeper’ as early as July 20 2020, although all other industries received these payments until September 27. This was justified by the government due to a subsidy which allowed Australian parents free childcare concluding on July 13 2020 (Stewart, 2020).
# - As a result of this, the government initiative which allowed Australians to withdraw from their superannuation during the pandemic was used by more women than men (AMP, 2020) (Batchelor, 2020). This has provided necessary support for women during the pandemic, however it has also widened the gender superannuation gap by 4%, with men having an average of 29% higher superannuation balance.
# All of these factors will likely have regressive long-term effects on advances that have made for equity and will likely lower global gross domestic product (GDP), as summarised by the ‘larger impacts’ section of Figure 2.1.1.

# %% [markdown]
# ![image.png](attachment:cbd1464d-ca40-432c-bbeb-3cd39480b3d5.png)

# %% [markdown]
# **Figure 2.2.1**

# %% [markdown]
# Figure 2.1.2 demonstrates how domestic responsibilities placed on women during the pandemic have widened the gender inequality gap.
# - Women already perform almost one third more of their normal working hours on additional unpaid work than men (WGEA, 2020), which is likely to increase during the COVID-19 pandemic due to social gender role norms (Madgavkar et al, 2020).
# - The child-care burden of teaching at home during lockdowns is more likely to be placed on and performed by women (Alon et al, 2020).
# - The ‘1.5 earner model’ describes the common situation where parents of young children earning sixty-thousand-dollar salaries or less each will lose part of their income, being as high as 90% or more, on childcare, taxation and government payments if the secondary earner were to work on the fourth day of the working week. This secondary earner is often the mother due to gender norms, disincentivizing her from working and increasing domestic responsibilities (Wood, Griffiths & Emslie, 2020). As more women continue to lose economic stability from the recession impacts outlined prior, this situation is likely to become more common following the end of the government’s childcare subsidies.

# %% [markdown]
# The COVID-19 pandemic has deteriorated conditions for women due to an increased threat of violence toward women. Firstly, the direct implication of the pandemic resulting in more people being encouraged and mandated to isolate to reduce the spread has placed women at a larger risk of domestic violence. Of women who have been reported physical or sexual violence since the beginnings of the pandemic in Australia, 66% are experiencing it for the first time, or it has escalated. Moreover, out of women who have reported coercive control, more than half have reported the acts began or escalated during the pandemic. In addition to this, violence toward women increases during times of economic downturn (WGEA, 2020). Lastly, the ability of women’s shelters to have capacity, or sufficient financial support, is less likely due to the nature of social distancing and the conditions of the economy (United Nations, 2020). Each of these impacts culminates to significantly worse conditions for women currently experiencing violence and increased risk to women who have yet to experience it.
#
# Evidently, the gendered impact of COVID-19 has been widely studied and addressed by the media and academia, specifically considering the short period of time the pandemic has been investigated for and lockdowns have been implemented. The problem has also been addressed and recognised at a global level by organisations such as the United Nations (United Nations, 2020) and the OECD (OECD, 2020). Despite this, there is a lack of government response, with many policies, as mentioned previously, increasing or ignoring the problem.

# %% [markdown]
# ## 2.2 Identify the system + stakeholders. For this, you will need to construct a “rich picture” that captures the essential elements.

# %% [markdown]
# The system described in figure 2.2.1 attempts to capture all elements in the system of Australian society that impact women following the Coronavirus pandemic. While this rich picture only attempts to unpack the larger system on an elementary level, it is evident the links between the pandemic and the wider community will have inexplicable impacts on women that may be different than their impacts on men. In addition, the figure does not explore the added layer of the global influences that impact Australia and how this fluidity in the system boundary increases the complexity of solving the issue.

# %% [markdown]
# ![image.png](attachment:3855375f-f1b2-4ad1-81e6-6462036e26c9.png)

# %% [markdown]
# **Figure 2.2.1**

# %% [markdown]
# ## 2.3 Identify current models or prevailing frames that are being used to address the problem

# %% [markdown]
# There are a range of prevailing frames which are preventing the problem of how COVID-19 has disproportionately impacted women from being solved or even addressed. These frames include the notion of focusing on the immediate problems rather than ensuring the stability of the future, gender stereotypes and the ideology that pandemics are a method of leveling inequalities. Furthermore, current models such as the male breadwinner model is the driving force of the policies and culture in Australia.

# %% [markdown]
# ## 2.4 Discuss how prevailing models/frames are preventing the problem from being fully addressed or solved

# %% [markdown]
# The COVID-19 pandemic is exacerbating the gender inequality experienced by women and there are numerous prevailing models and frames which prevent this shadow pandemic from being resolved or even addressed. Policy makers, media and official authorities have shifted the focus from all other social and environmental issues that are taking place and drawing all the attention towards the global pandemic (Fabrizio et al., 2020). The notion that governments need to focus on the immediate problems to ensure the stability of the society rather than solving the anticipated problems of the future is hindering the possibility of even addressing this issue (Colins College, 2017). Policy makers are more focused towards creating solutions to contain and regulate the spread of the virus and are refusing to focus on aiding women who have been disproportionately affected by the COVID-19 outbreak (Fabrizio et al., 2020).
#
# Additionally, stereotypes have significantly exacerbated the socially prescribed care roles of women (Alleman & Rumble, 2020). As detailed in section 2.2, social distancing guidelines have forced children to transition into an online learning environment, thus, women are pressured into leaving or postponing their careers to prioritize the education of their children (WGEA, 2020). Moreover, women who have been the frontline responders during this pandemic are unfairly limited to the household and burdened to take on all care responsibilities including the maintaining of hygiene and sanitisation (Wamera, 2020).
#
# In the text ‘The Great Lever’, the historian Walter Scheidel details the notion that a catastrophic event such as a plague are forces that will decrease inequality through a process of leveling. By studying the patterns that have occurred in history, Scheidel explains that “inequality never dies peacefully” (Scheidel, 2017). The historian exemplifies this idea through the study of The Black Plague and concluded that it led to the erosion of status barriers and brought about a leveling in society (Scheidel, 2017). The elite ranks shrank in fortune and size and the poorer were given opportunities to earn better pay (Scheidel, 2017). One can draw parallels between this epidemic with the COVID-19 pandemic and believe that the virus will bring about a ‘levelling’ and counteract the inequality women are facing. However, this will not be the case as disregarding gender inequality can have significant consequences on Australia’s economy and lower the GDP (WGEA, 2020).
#
# Another model that has seriously impeded the issue of gender inequality from being resolved is the male breadwinner model which has been heavily institutionalized and reinforced in Australia’s policies and culture (Broomhill & Sharp, 2005). This is greatly evident in women’s access to unemployment benefits as “under the breadwinner model, the institutional structure reinforces the supposition that a woman will be, at best, a secondary earner and so her entitlement may be conditional upon either her husband’s labour force status and/or his income” (Mitchell, n.d.). The male bead winner model is a gender division ideal in which the man is given the responsibility of earning an income to support his family while the women take on domestic labour and care for the family (Parliament of Australia, 2016). The parliament of Australia states that “policy development is still premised on the assumption of the male breadwinner model” (Parliament of Australia, 2020). Consequently, this model creates a power imbalance in the household where men assume the power, this imbalance can create an unhealthy stress in the relationship leading to marital conflicts. Thus, when marital conflicts arise a high level of negative interactions occur including domestic violence which positions women in a vulnerable situation (Cerrato & Cifre, 2018).

# %% [markdown]
# # 3. Conceptual Models

# %% [markdown]
# ## 3.1 Based on your self-study of the supermarket of models, explain the three models that you have chosen to look at the problem

# %% [markdown]
# *Markov Models*
#
# The Markov model is a model that determines the future state of sequences by considering the previous states. It holds the assumptions that there are a limited number of states. It is not a simple cycle, since eventually any state can get from one to another.
# Due to the fact that inequality is an issue, especially for women, the COVID-19 situation made it worse for them. As mentioned earlier in section 2.1, women are already affected in the job market negatively, and the pandemic would have made it worse. The Markov model is a good way to predict future events, while taking the previous events in the same sequence into account. This model shows that future states change according to previous states. Therefore, this is a good method to predict the impact of COVID-19 on women in certain areas.

# %% [markdown]
# *Preferential Attachment Models*
#
# Preferential attachment models reflect circumstances in which nodes are biased towards other nodes that they connect with. This results in a network in which those with more nodes will continually receive more connections (Wang, 2020). This model was chosen due to its ability to emulate unequal power distributions in models. In the circumstance of women’s employment, this can be applied to highlight the prepetual effect of discrimination and disadvantage once some degree of inequality is already in effect.
#
# *System Dynamic models*
#
# System dynamic models use the probability of several influencing factors to determine the rate of increase/decrease over time. It can be used to predict outcomes when one or more factors within a system are altered.

# %% [markdown]
# ![image.png](attachment:9bbd1eb4-0a21-470e-8a7a-3084146f9a70.png)

# %% [markdown]
# **Figure 3.1.1: an example of a causal loop diagram. (John Sterman, 2001)**

# %% [markdown]
# ## 3.2 Explain how each of the three models works (brief) and how it will be applied in your case.

# %% [markdown]
# *Markov model*
#
#  Since Markov models are  modelled with random probability situations, data from the past will be needed to show the reason for the current situation with the inequality issue caused by COVID-19. An example of the usage of the Markov model would be finding out the percentage of bored versus alert students in a class. The percentage would change over time, and this could be predicted by figuring out the trend in the change in each variable, which are the alert students and the bored students. 75% of health professionals and 88% of midwifery and nursing professionals in Australia are women as mentioned in section 2.1. This increases their risk of getting infected and it leaves them vulnerable to abuse of different sorts, especially during the pandemic times. (Unicef, 2020) Due to the coronavirus, domestic violence has increased on women, furthermore, many support services have been closed too (Unicef, 2020). With the use of Markov models, a trend can be predicted in the occurrences of these cases, and it can help taking precautions early on the issue to prevent from further harm happening.

# %% [markdown]
# *Preferential Attachment Models*
#
# Preferential attachment models work by taking the idea that an entity entering the network will have some probability of creating a new form, and some probability of connecting with an existing entity. As this probability accumulates, new nodes or entities joining will then prefer to connect with entities that already have connections, creating a preferential attachment. This can be applied to examine the effect on women-dominated industries in the economy when government investment and stimulus is distributed unequally, favouring male-dominated industries. Using preferential attachment models to investigate this issue can demonstrate its long-term effects on inequality in women’s employment.
#
#
#
# *System Dynamic models*
#
# System dynamic models can be used to predict outcomes when factors within a system are changed. This can be used in the case of gender inequality to determine what the best courses of action are when dealing with domestic abuse, wage/job loss, and front line workers, all of which are affecting women disproportionately more than men in the COVID-19 climate. The result is an increase in domestic violence cases against women with no real increased access to help. If proper avenues for help are implemented well, the proportion of women who seek help will increase. This change in the probability to seek help can be plotted in a system dynamic model to predict outcomes of not only the increase of women seeking help, but also the drop in domestic abuse cases because help has been made easier to find.

# %% [markdown]
# ## 3.3 Describe any data sources (real or hypothetical) that are needed to construct the three models. Use illustrative drawings and diagrams where possible

# %% [markdown]
# Particularly for the Markov model, histograms would be a good representation to show the frequency of data in a continuous data set. In addition to this, there are some specific data points that will be necessary to construct System Dynamic,  AGM and Markov models:
#
# - Increase of domestic abuse reports
# - % of women/men working frontline jobs (nurses etc.)
# - % of women/men working casual jobs
# - % of women/men that are stay-at-home parents
# - Access to sanitary products
# - Gov. financial assistance for casual/frontline workers + support for loss of job
# - Information from past events relating to the job market for women.

# %% [markdown]
# ![image.png](attachment:c74bd51a-34dd-41c4-8bf9-604dbf20e3c5.png)

# %% [markdown]
# **Figure 3.3.1.**

# %% [markdown]
# This histogram shows the frequency of domestic violence experienced by women during the pandemic. Measures like these can give a good indication of current states of an issue. Looking at the trend it shows, the Markov model can be used to determine future possibilities regarding certain issues, like the impact of COVID-19 on women. It shows that during the pandemic, there have been many cases of domestic violence on women. The Markov model can predict frequencies of domestic violence on women for the future, during and after pandemic times.

# %% [markdown]
# # 4. Implementation

# %% [markdown]
# ## 4.1 Describe the mathematical and/or statistical implementation of your three models. This should be done using Python code.

# %% [markdown]
# As suggested in research in sections 2 and 3, this issue is signficantly broad. From here onward, the report investigates the disproportionate **economic** effect on women following COVID-19 in Australia, in order to remain consistent and specific. It should be noted this is not the only impact that has and will continue to occur to women due to COVID-19.

# %% [markdown]
# ### 4.1.1 Preferential Attachment Model

# %% [markdown]
# This Preferential Attachment network model demonstrates the impact of gender bias in current government policies, as outlined in the 2020-21 budget, and how it may perpetuate a disproportionate allocation of resources if further government policies are extensions of current ones. The idea that preferential attachment in policy can create worsened inequality is perpetuated by Markey-Towler (n.d.) and has previously been presented to the Parliament of Australia. The gendered impact of the 2020/21 budget has been heavily researched and critisised (National Foundation of Australian Women, 2020), which just one snapshot suggesting taxation cuts will favour men by 60%.
#
# The degree of bias that the nodes are conditioned to are estimated to be 0.6. This figure outlines the likelihood future government policies or stances will be extensions of, or built upon, those spending and taxation trends introduced in 2020/21. Therefore:
#
# - Initial nodes = current major government policies in 2020/21 budget
# - Additional nodes = future government policies
#
# This code has been edited from Molak (2017).

# %%
# SECTION 1 - IMPORTS

import networkx as nx
import numpy as np
import random as rd
import matplotlib.pyplot as plt
import warnings

# If you are using Jupyter Notebook you may find following two lines useful:
# warnings.filterwarnings('ignore')
# % matplotlib inline

# ____________________________________________________________________

# %%
# SECTION 2 - VISUALISATION FUNCTION

def k_distrib(graph=G, scale='lin', colour='#40a6d1', alpha=.8, expct_lo=1, expct_hi=10, expct_const=1):
    plt.close()
    num_nodes = graph.number_of_nodes()
    max_degree = 0
    # Calculate the maximum degree to know the range of x-axis
    for n in graph.nodes():
        if graph.degree(n) > max_degree:
            max_degree = graph.degree(n)
    # X-axis and y-axis values
    x = []
    y_tmp = []
    # loop for all degrees until the maximum to compute the portion of nodes for that degree
    for i in range(max_degree+1):
        x.append(i)
        y_tmp.append(0)
        for n in graph.nodes():
            if graph.degree(n) == i:
                y_tmp[i] += 1
        y = [i/num_nodes for i in y_tmp]
    # Plot the graph
    deg, = plt.plot(x, y,label='Degree distribution',linewidth=0, marker='o',markersize=8, color=colour, alpha=alpha)
    # Check for the lin / log parameter and set axes scale
    if scale == 'log':
        plt.xscale('log')
        plt.yscale('log')
        plt.title('Degree distribution (log-log scale)')
        # add theoretical distribution line k^-3
        w = [a for a in range(expct_lo,expct_hi)]
        z = []
        for i in w:
            x = (i**-3) * expct_const # set line's length and fit intercept
            z.append(x)

        plt.plot(w,z, 'k-', color='#7f7f7f')
    else:
        plt.title('Degree distribution (linear scale)')


    plt.ylabel('P(k)')
    plt.xlabel('k')
    plt.show()

# ____________________________________________________________________

# %%
# SECTION 3 - BA ALGORITHM

print("***\nWelcome to Barabási–Albert (BA) model simulation\nAuthor: Aleksander Molak (2017)\n")

# Get parameters
init_nodes = int(input("Please type in the initial number of nodes (m_0): "))
final_nodes = int(input("\nPlease type in the final number of nodes: "))
m_parameter = int(input("\nPlease type in the value ozf m parameter (m<=m_0): "))
print("\n")
print("Creating initial graph...")
G = nx.complete_graph(init_nodes)

print("Graph created. Number of nodes: {}".format(len(G.nodes())))
print("Adding nodes...")

def rand_prob_node():
    nodes_probs = []
    for node in G.nodes():
        node_degr = G.degree(node)
        #print(node_degr)
        node_proba = node_degr / (2 * len(G.edges()))

        
       
        print("Node proba is: {}".format(node_proba))
        nodes_probs.append(node_proba)
        #print("Nodes probablities: {}".format(nodes_probs))
    random_proba_node = np.random.choice(G.nodes(),p=nodes_probs)
    #print("Randomly selected node is: {}".format(random_proba_node))
    return random_proba_node
# Out:
# ***
# Welcome to Barabási–Albert (BA) model simulation
# Author: Aleksander Molak (2017)
# Please type in the initial number of nodes (m_0):  300
#
# Please type in the final number of nodes:  300
#
# Please type in the value ozf m parameter (m<=m_0):  2
# Creating initial graph...
# Graph created. Number of nodes: 300
# Adding nodes...

# %%
def add_edge():
        if len(G.edges()) == 0:
            random_proba_node = 0
        else:
            random_proba_node = rand_prob_node()
        new_edge = (random_proba_node, new_node)
        if new_edge in G.edges():
            print("Thats not how you build a wall")
            add_edge()
        else:
            print("Mazel Tov!")
            G.add_edge(new_node, random_proba_node)
            print("Edge added: {} {}".format(new_node + 1, random_proba_node))

count = 0
new_node = init_nodes

for f in range(final_nodes - init_nodes):
    print("----------> Step {} <----------".format(count))
    G.add_node(init_nodes + count)
    print("Node added: {}".format(init_nodes + count + 1))
    count += 1
    for e in range(0, m_parameter):
        add_edge()
    new_node += 1


print("\nFinal number of nodes ({}) reached".format(len(G.nodes())))

print("\n\nThanks!\n")
# Out:
# Final number of nodes (300) reached
#
#
# Thanks!

# %%
import networkx as nx
import numpy as np
import random as rd
import matplotlib.pyplot as plt
import warnings
def k_distrib(graph=G, scale='lin', colour='#40a6d1', alpha=.8, expct_lo=1, expct_hi=10, expct_const=1):
    plt.close()
    num_nodes = graph.number_of_nodes()
    max_degree = 0
    # Calculate the maximum degree to know the range of x-axis
    for n in graph.nodes():
        if graph.degree(n) > max_degree:
            max_degree = graph.degree(n)
    # X-axis and y-axis values
    x = []
    y_tmp = []
    # loop for all degrees until the maximum to compute the portion of nodes for that degree
    for i in range(max_degree+1):
        x.append(i)
        y_tmp.append(0)
        for n in graph.nodes():
            if graph.degree(n) == i:
                y_tmp[i] += 1
        y = [i/num_nodes for i in y_tmp]
    # Plot the graph
    deg, = plt.plot(x, y,label='Degree distribution',linewidth=0, marker='o',markersize=8, color=colour, alpha=alpha)
    # Check for the lin / log parameter and set axes scale
    if scale == 'log':
        plt.xscale('log')
        plt.yscale('log')
        plt.title('Degree distribution (log-log scale)')
        # add theoretical distribution line k^-3
        w = [a for a in range(expct_lo,expct_hi)]
        z = []
        for i in w:
            x = (i**-3) * expct_const # set line's length and fit intercept
            z.append(x)

        plt.plot(w,z, 'k-', color='#7f7f7f')
    else:
        plt.title('Degree distribution (linear scale)')


    plt.ylabel('P(k)')
    plt.xlabel('k')
    plt.show()
print("***\nWelcome to Barabási–Albert (BA) model simulation\nAuthor: Aleksander Molak (2017)\n")

# Get parameters
init_nodes = int(input("Please type in the initial number of nodes (m_0): "))
final_nodes = int(input("\nPlease type in the final number of nodes: "))
m_parameter = int(input("\nPlease type in the value ozf m parameter (m<=m_0): "))
print("\n")
print("Creating initial graph...")
G = nx.complete_graph(init_nodes)

print("Graph created. Number of nodes: {}".format(len(G.nodes())))
print("Adding nodes...")

def rand_prob_node():
    nodes_probs = []
    for node in G.nodes():
        node_degr = G.degree(node)
        #print(node_degr)
        node_proba = node_degr / (2 * len(G.edges()))
        
        G = nx.complete_graph(5)
        preds = nx.preferential_attachment(G, [(0, 1), (2, 3)])
        for u, v, p in preds:
        print(f"({0.6}, {0.4}) -> {16}")
        (0, 1) -> 16
        (2, 3) -> 16
        
        
        print(node_proba)
        #print("Node proba is: {}".format(node_proba))
        nodes_probs.append(node_proba)
        #print("Nodes probablities: {}".format(nodes_probs))
    random_proba_node = np.random.choice(G.nodes(),p=nodes_probs)
    #print("Randomly selected node is: {}".format(random_proba_node))
    return random_proba_node
def add_edge():
        if len(G.edges()) == 0:
            random_proba_node = 0
        else:
            random_proba_node = rand_prob_node()
        new_edge = (random_proba_node, new_node)
        if new_edge in G.edges():
            print("Thats not how you build a wall")
            add_edge()
        else:
            print("Mazel Tov!")
            G.add_edge(new_node, random_proba_node)
            print("Edge added: {} {}".format(new_node + 1, random_proba_node))

count = 0
new_node = init_nodes

for f in range(final_nodes - init_nodes):
    print("----------> Step {} <----------".format(count))
    G.add_node(init_nodes + count)
    print("Node added: {}".format(init_nodes + count + 1))
    count += 1
    for e in range(0, m_parameter):
        add_edge()
    new_node += 1


print("\nFinal number of nodes ({}) reached".format(len(G.nodes())))

print("\n\nThanks!\n")
# Out:
#   File "<ipython-input-7-b0a25a741f70>", line 70
#     print(f"({0.6}, {0.4}) -> {16}")
#     ^
# IndentationError: expected an indented block

# %%
k_distrib(graph=G,colour='#40a6d1',alpha=.8)

# %%
k_distrib(graph=G,colour='#40a6d1', scale='log',alpha=.8, expct_lo=3, expct_hi=14, expct_const=8)

# %%
nx.draw(G, node_size=50, with_labels=0, alpha=0.6, node_color="#40a6d1", edge_color="#FFA500")

# %% [markdown]
# ### 4.1.2 Markov Model
#
# This model depicts the liklihood that the job market will worsen for women following COVID-19.

# %%
import numpy as np
import random as rm

# The statespace
states = ["Stable","Worse","Improved"]

# Possible sequences of events
transitionName = [["SS","SW","SI"],["WS","WW","WI"],["IS","IW","II"]]

# Probabilities matrix (transition matrix)
transitionMatrix = [[0.2,0.6,0.2],[0.1,0.6,0.3],[0.2,0.7,0.1]]

if sum(transitionMatrix[0])+sum(transitionMatrix[1])+sum(transitionMatrix[1]) != 3:
    print("Somewhere, something went wrong. Transition matrix, perhaps?")
    
# A function that implements the Markov model to forecast the state/mood.
def activity_forecast(days):
    # Choose the starting state
    JobMarketState = "Stable"
    print("Start state: " + JobMarketState)
    # Shall store the sequence of states taken. So, this only has the starting state for now.
    stateList = [JobMarketState]
    i = 0
    # To calculate the probability of the activityList
    prob = 1
    
    while i != days:
        if JobMarketState == "Stable":
            change = np.random.choice(transitionName[0],replace=True,p=transitionMatrix[0])
            if change == "SS":
                prob = prob * 0.2
                stateList.append("Stable")
                pass
            elif change == "SW":
                prob = prob * 0.6
                JobMarketState = "Worse"
                stateList.append("Worse")
            else:
                prob = prob * 0.2
                JobMarketState = "Improved"
                stateList.append("Improved")
        elif JobMarketState == "Worse":
            change = np.random.choice(transitionName[1],replace=True,p=transitionMatrix[1])
            if change == "WW":
                prob = prob * 0.5
                stateList.append("Worse")
                pass
            elif change == "WS":
                prob = prob * 0.2
                JobMarketState = "Stable"
                stateList.append("Stable")
            else:
                prob = prob * 0.3
                JobMarketState = "Improved"
                stateList.append("Improved")
        elif JobMarketState == "Improved":
            change = np.random.choice(transitionName[2],replace=True,p=transitionMatrix[2])
            if change == "II":
                prob = prob * 0.1
                stateList.append("Improved")
                pass
            elif change == "IS":
                prob = prob * 0.2
                JobMarketState = "Stable"
                stateList.append("Stable")
            else:
                prob = prob * 0.7
                JobMarketState = "Worse"
                stateList.append("Worse")
        i += 1  
    print("Possible states: " + str(stateList))
    print("End state after "+ str(days) + " days: " + JobMarketState)
    print("Probability of the possible sequence of states: " + str(prob))




def activity_forecast(days):
    # Choose the starting state
    JobMarketState = "Stable"
    stateList = [JobMarketState]
    i = 0
    prob = 1
    while i != days:
        if JobMarketState == "Stable":
            change = np.random.choice(transitionName[0],replace=True,p=transitionMatrix[0])
            if change == "SS":
                prob = prob * 0.2
                stateList.append("Stable")
                pass
            elif change == "SW":
                prob = prob * 0.6
                JobMarketState = "Worse"
                stateList.append("Worse")
            else:
                prob = prob * 0.2
                JobMarketState = "Improved"
                stateList.append("Improved")
        elif JobMarketState == "Worse":
            change = np.random.choice(transitionName[1],replace=True,p=transitionMatrix[1])
            if change == "WW":
                prob = prob * 0.5
                stateList.append("Worse")
                pass
            elif change == "WS":
                prob = prob * 0.2
                JobMarketState = "Stable"
                stateList.append("Stable")
            else:
                prob = prob * 0.3
                JobMarketState = "Improved"
                stateList.append("Improved")
        elif JobMarketState == "Improved":
            change = np.random.choice(transitionName[2],replace=True,p=transitionMatrix[2])
            if change == "II":
                prob = prob * 0.1
                stateList.append("Improved")
                pass
            elif change == "IS":
                prob = prob * 0.2
                JobMarketState = "Stable"
                stateList.append("Stable")
            else:
                prob = prob * 0.7
                JobMarketState = "Worse"
                stateList.append("Worse")
        i += 1    
    return stateList

# To save every stateList
list_state = []
count = 0

# `Range` starts from the first count up until but excluding the last count
for iterations in range(1,10000):
        list_state.append(activity_forecast(2))

# Check out all the `activityList` we collected    
#print(list_activity)

# Iterate through the list to get a count of all activities ending in state:'Run'
for smaller_list in list_state:
    if(smaller_list[2] == "Worse"):
        count += 1

# Calculate the probability of starting from state:'Stable' and ending at state:'Worse'
percentage = (count/10000) * 100
print("The probability of starting at state:'Stable' and ending at state:'Worse'= " + str(percentage) + "%")
# Out:
# The probability of starting at state:'Stable' and ending at state:'Worse'= 61.71%

# %% [markdown]
# ### 4.1.3 System Dynamic Model

# %% [markdown]
# Using a basic system dynamic model (such as a causal loop diagram) (Dubois, 2017), we can depict the interrelatedness of the variables that create a system. Through the implementation of the referenced python code, we can then create and alter new variables to imitate changing circumstances within a model.
#
# Each node represents a variable, or an effect, that is brought on by the effect of the node(s) previous, and each connecting arrow represents the degree of effect one node has on another. Thus, by changing the degree of effect of one node and running the code, we can document the effect this change has on all other nodes.
#
# In relation to our chosen issue of Gender inequality post COVID-19, this can be used to predict (to an extent) the potential changes needed to increase gender equality. For example, this could be used to display the increase in women returning to the same job or seeking a more secure job having experienced the loss of a casual job at the start of the pandemic. Additionally, it can be used to plot the progression back to normality that female workers face, and how long it may take for the female working population to fully recover from the job losses experienced through Covid.

# %%
from setuptools import setup

setup(name='cldx',
      version='0.1',
      description='Causal Loop Diagrams with networkx',
      url='http://github.com/fabid/cldx',
      author='Fabian Dubois',
      author_email='fabian.dubois@gmail.com',
      license='MIT',
      packages=['cldx'],
      install_requires=[
            'matplotlib == 2.2.2',
            'numpy >=1.7.1',
            'networkx >= 2.1',
            'pygraphviz >= 1.3.1',
      ],
      zip_safe=False)
# Out:
# /Users/amberrizvi/opt/anaconda3/lib/python3.8/site-packages/setuptools/distutils_patch.py:25: UserWarning: Distutils was imported before Setuptools. This usage is discouraged and may exhibit undesirable behaviors or errors. Please use Setuptools' objects directly or at least import Setuptools first.
#   warnings.warn(
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/amberrizvi/opt/anaconda3/lib/python3.8/distutils/fancy_getopt.py", line 233, in getopt
#     opts, args = getopt.getopt(args, short_opts, self.long_opts)
#   File "/Users/amberrizvi/opt/anaconda3/lib/python3.8/getopt.py", line 95, in getopt
#     opts, args = do_shorts(opts, args[0][1:], shortopts, args[1:])
#   File "/Users/amberrizvi/opt/anaconda3/lib/python3.8/getopt.py", line 195, in do_shorts
#     if short_has_arg(opt, shortopts):
# ...

# %%
import io

import networkx as nx
import pygraphviz as pgv
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-2764ecf498b5> in <module>
#       2
#       3 import networkx as nx
# ----> 4 import pygraphviz as pgv
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'pygraphviz'

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.patches import FancyArrow, Arc


class CausalLoopDiagram:
    def __init__(self):
        """
        Initializes an empty Causal Loop Diagram
        """
        self.graph = nx.DiGraph()

    def add_causal_links(self, links):
        """
        Add causal links from a list of links
        Parameters
        ----------
        links : list of (souce, target, gain) tuples, default None
            Sources and targets of the causal links.
            Sign of the gain defines if source and target move together or in opposite direction.
        """
        self.graph.add_edges_from(
            [(l[0], l[1], {'gain': l[2]}) for l in links])

    def to_graphviz(self):
        g = self.graph.copy()
        for e in g.edges:
            self._prepare_edge(g, e)
        gv = nx.nx_agraph.to_agraph(g)
        return gv

    def _prepare_edge(self, g, edge):
        edge_data = g.get_edge_data(edge[0], edge[1])
        if edge_data['gain'] > 0:
            edge_data['label'] = '+'
        else:
            edge_data['label'] = '-'
            edge_data['arrowhead'] = 'empty'

    def draw(self, filename=None, loops=[]):
        """
        Draw causal loop diagram.
        Parameters
        ----------
        filename : string, default None
            If specified, will output an image file. Recommended extension: png
        loops : list of loops, default []
            If specified, will draw markers for reinforcing and stabilizing loops.
            Note: this is beta and layout is not really good.
        """
        gv = self.to_graphviz()
        gv.layout(prog='dot')

        asdot = str(gv.draw(format='dot'))
        start = asdot.find('bb="')
        end = asdot.find('"];')
        size = [float(x) for x in asdot[start+4: end].split(',')[2:]]

        png = gv.draw(format='png')
        if filename:
            gv.draw(filename)

        tempBuff = io.BytesIO()
        tempBuff.write(png)
        tempBuff.seek(0)
        img = mpimg.imread(tempBuff)
        plt.figure(figsize=(12, 12))
        plt.imshow(img, interpolation="bicubic")
        imsize = [img.shape[1], img.shape[0]]
        for loop in loops:
            self._draw_loop(gv, loop, size, imsize)

    def _draw_loop(self, gv, loop, size, imsize):
        coords = [gv.get_node(n).attr['pos'].split(',') for n in loop['nodes']]
        x = np.mean([float(c[0]) for c in coords])
        y = np.mean([float(c[1]) for c in coords])
        x = x * imsize[0] / size[0]
        y = imsize[1] - y * imsize[1] / size[1]
        head = FancyArrow(x + 15, y, 0, -1, head_width=10, color="k")
        arrow = Arc((x, y), 30, 30, theta1=0, theta2=270)
        plt.gca().add_patch(arrow)
        plt.gca().add_patch(head)
        plt.text(x - 5, y + 4, loop['type'], fontsize=8)

    def _get_loop_type(self, loop):
        sign = np.product(
            [self.graph.get_edge_data(l, loop[(i + 1) % len(loop)])['gain']
             for i, l in enumerate(loop)])
        return 'R' if sign > 0 else 'S'

    def find_loops(self):
        """
        Find loops (cycles) in the causal loop diagram.
        It returns a list of loops described by a list of nodes and type.
        `R` for reinforcing or `S` for stabilizing
        """
        loops = nx.simple_cycles(self.graph)
        return [{'nodes': l, 'type': self._get_loop_type(l)} for l in loops]

# %% [markdown]
# # 5. Scenario analysis, sensitivity + uncertainty evaluation

# %% [markdown]
# ## 5.1 Establish baseline parameter sets and or configuration for output scenarios

# %% [markdown]
# ### 5.1.1 Preferential Attachment Model

# %% [markdown]
# Here, it is evident a preferential attachment occurs between nodes with bias, representing favoured policies, and a lack of connectivity from nodes without.
#
# In the 2020/21 budget, there were approximately 19 major budgetary policies of taxation and spending. Assuming the following year’s budget will also include 19 major policies, each branching off about 2 of previous year’s policies, the model will look as outlined above. If there were more policies in each budget, the preferential attachment should change in the same proportion as the model in 4.1.
#
# However, the would differ if the degree of bias that additional nodes connect to changes. If this bias toward former policies increases, the model would look like this, highlighting its sensitivity.

# %% [markdown]
# ### 5.1.2 Markov Model

# %% [markdown]
# ### 5.1.3 System Dynamic Model

# %% [markdown]
# Causal loop diagrams focus on showing the overall changes experienced in a system when one smaller change is made. Therefore, there are many more niche parameters than some other models. These include the likelihood of women entering/staying or leaving a certain industry, job flexibility following COVID and maybe most important during the COVID pandemic, the percentage difference in full-time/part-time or casual women employees compared to men.
# When taking all these parameters into account, we can plot the current trajectory for women’s jobs as well as the potential trajectory if some small factors were changed.
#
# **Output scenario for current trajectory**
#
# With current parameters considered, the current trajectory for women’s inequality post COVID means the gender equality gap will continue to increase. This is in terms of not only the pay gap, but the percent of women in stable (Full-time or part-time) jobs will continue to decrease, as well as the overall unemployment rate of women to men. This will effectively perpetuate the gender norms of women going into casual work in front-line/caregiver roles during/post COVID.
#
# **Potential output scenarios**
#
# This model could be set up to explore a wide range of varying scenarios that produce many outcomes. For instance, if new government legislation was brought in to flatten the pay gap, it would lead to less female casual workers and therefore less job loss within that demographic. In addition, if the stigma surrounding what gender should perform in what job was to be dismantled, a similar effect would take place and would lead to a more equal work environment across the board of all industries.

# %% [markdown]
# ## 5.2 Perform a basic sensitivity analysis, i.e., identify with parameters are most sensitive/insensitive for the outputs

# %% [markdown]
# ### 5.2.1 Preferential Attachment Model

# %% [markdown]
# As explored in the previous section, this model is sensitive toward changes in the bias. This is what will cause the degree of preferential attachment, and consequently inequality.
#
# A large assumption of the original model is the idea that 60% of future policies will continue the trend of current government budget policies. This can be considered a fair estimate while Australia recovers from recession, as many conservative policies during downturns centre on investment in infrastructure and taxation cuts due to the nature of former economic downturns that have been experienced. However, as this is foremost a ‘health crisis’ as opposed to a financial one, there is a likely margin of error in this assumption if governments in coming years do not follow 60% of  the spending and taxation trends of former policies.
#
# Here, it is important to note the idea that each of these models alone are less useful than they are cumulatively. This is because individually, this model is simply a forecast based on current statistics and trends. The models should be examined in conjunction with each other to reveal true insights as opposed to specific speculative data.

# %% [markdown]
# ### 5.2.2 Markov Model

# %% [markdown]
# ### 5.2.3 System Dynamic Model

# %% [markdown]
# ***Sensitive***
#
# **Level of training received**: As women are majority casual workers, they often do not receive the same level of training as men in part or full-time positions would. If this were to change, women would not only be able to progress their careers easier, but they would be able to ease into a part or full-time position.
#
#
# **Likelihood of women entering a specific industry**: There are many industries that are ‘marketed’ towards men, and others that are ‘marketed’ towards women. Women are more likely to enter a nursing or caregiving industry while men are more likely to enter business. If this was to change, we will see a large change in casual workers that are women and the presence of women in these male dominated industries would help flatten the inequality gap.
#
# **Perpetuation OR Decrease of Gender norms**: The state of current gender norms heading into the future is one of the biggest influences and inputs. If gender norms are to be perpetuated in the current way they are, not much will change or at least not for a very long time. However, if gender norms can be changed to allow women to be paid equally, and to enter the same types of jobs in the same way as men are, then gender inequality will drastically change in a positive manner.
#
#
# ***Insensitive***
#
# **Job flexibility following covid**: This isn’t a sensitive input as the same or similar rules would apply to the whole population, meaning there would not be much difference to overall outputs.

# %% [markdown]
# # 6. Proposed solutions

# %% [markdown]
# ## 6.1 Discuss potential portfolio of solutions based on your previous analysis

# %% [markdown]
# *Preferential attachment model*
#
# Based on predictions from the preferential attachment model, there is likely to be a perpetuation and worsening of gender inequity based on the assumption majority of later government policies will follow the trend current 2020/21 policies. While the degree to which this may occur is dependent on the factors examined in sensitivity analysis, there are a number of actions which can be taken to curb regressions in women’s equality in the economy following COVID-19.
#
# - Re-structuring the lens of this recession to understand how it negatively impacts women to a larger extent is essential before any solution is put in place. Modelling such as this should be continued and revised in order to examine this.
# - One suggestion of significance is the re-introduction of the Women’s Budget Statement. This would purposely analyse and bring to fore the significance of these issues in context of the larger economy, prompting more actions, specifically as this recession is projected to impact women disproportionately. This document was released alongside the annual budget from 1984-2014 in Australia, analysing the impact of budgetary policy on women and the benefits it can provide for equity. Since it’s cessation to be included, the statement has been written by independent organisations (National Foundation for Australian Women, 2020), however lacks the breadth of information held by the government.
# - Revising the nature of the COVID-19 recession on the Australian economy is also integral, as it is a health crisis that has occured in a time where change in the foundations of the Australian economy has occurred. Understanding this societal shift in Australia since recession policies were first introduced is important, as women’s participation rates have increased, and the economy can benefit from the refocus toward social infrastructure such as education and healthcare and away from mining and physical infrastructure.

# %% [markdown]
# *Markov Model*
#
# Because of the coronavirus, the recession caused mass job losses. Especially for women, they were specifically more susceptible to these job losses, as explored in section 2. The repercussions of this are far reaching on women’s unpaid work, and overall gender inequality.
#
# The markov model showed the probabilities of future states taking the past and current state into consideration. With those probabilities, it can be possible to propose solutions for assuring a positive future for women in the job market. These could include more initiatives and policies aimed at women, as they one of the ‘hardest hit’ from the COVID-19 recession, rather than the male-dominated industries that funding is currently targeted at. Moreover, in the longer term, efforts to ‘de-segregate’ the workforce, that is, pushing for more women in male industries and vise versa, could assist reducing the concentrated impact that occurs when sectors such as childcare face difficulty due to lockdowns.

# %% [markdown]
# *System Dynamic Model*
#
# There are many possible solutions that can be hypothesised by looking at the previous System dynamic models. One solution is the implementation of a degree of government intervention to change the stigma surrounding specific job types and what genders are attracted to them. This would however require a degree of government funding and may not be practical when considering the degree of change this may make. As a result, it may be necessary to push change amongst the private sector, understanding the responsibilities from all sectors of society to endorse positive change. This can be targeted toward issues such as the gender pay gap in order to make meaningful progression against inequality.

# %% [markdown]
# Subsequently, it is evident how many-model thinking can provide a variety of insights into problems women face in the current economic state. Each of the three models point toward the necessity of long term, structural government change in order to alter the environment of inequality. This verifies the integral nature of the government as part of any solution that target’s the economy, as they are the regulator.

# %% [markdown]
# # 7. Reflection on group + individual approach to assignment

# %% [markdown]
# ### 7.1 Amber Rizvi reflection

# %% [markdown]
# In regards to contribution, I undertook the Agent-based model research with another team member, which we had both found quite challenging and beyond our scope in Python code-writing. However, following discussion with group members and our lecturer, we concluded it may be more beneficial to look into other models to use, specifically Long-tail distributions. This was actually quite successful, as I was able to gain an understanding of how to both models worked yet was still able to develop Python skills at my own pace, as well as ensuring the integrity of the report.
#
# A significant benefit of this project, I believe, is that I am now more aware about my political surroundings by assessing them through the lens of models. A poignant example of this is the Prisoners Dilemma theory applied to political advertising, or the Blotto game theory applied to tackling COVID-19. Through these examples, I have become more curious about how I can apply modelling beyond this subject and how it can benefit my career.
#
# In addition to these benefits, there were a handful of challenges to this assignment. One of significance was keeping updated with group work when we were all remotely working online. This made it difficult to verbally explain our thoughts, share code, and find times to discuss. Our group overcame this idea by scheduling regular meeting times and creating collaborative documents to share links and ideas.
#
# I believe if I were to face a real-world issue, and needed modelling to tackle it, I would follow a process similar to how this assignment was set up, that is, firstly researching then using a many-model approach. Through this, I would be able to investigate the contrast between results, possibly accounting for the individual bias, misconception or errors that one model alone holds.

# %% [markdown]
# ### 7.2 Shaanza Bhatti reflection

# %% [markdown]
# This semester, our topic for our assignment was the impact of the coronavirus on women in different areas of their lives. We used different models to show the changes came about after the COVID-19 occurred.
#
# I used the markov model to show the change in the job market for women after COVID-19, and how it could possibly change in the future. It is a model that explains the probability of any state in the sequence which depends on the previous states. It was not difficult finding statistics and information for the effect of the coronavirus on the job market for women, since it’s something that is still going on. However, trying to figure out the code for Python to represent the whole model and situation was a little hard. It could be because I do not know much about how to use Python, but also because there were different ways in which I found examples to help me with. There are different ways a markov model can be represented on Python and finding the one that most fit our case was a little challenging.
#
# The other members focused on other models which were the preferential model and system-dynamic model. There were different scenarios used for those models to represent specific issues within the coronavirus issue regarding women.
#
# There were more positives than negatives in this project. It was a good learning experience all around, with the coding and the models. The models also helped understand the real-life issues that are going on in this time, and future possibilities of where things can lead to.

# %% [markdown]
# ### 7.3 Vanisri Kannan reflection

# %% [markdown]
# In the completion of this group assignment, I have contributed by undertaking research into a model that can be implemented to address and resolve our social issue, along with another member of the team. Initially, we had planned on looking at solving our social problem through an agent-based model; however, implementing this model was challenging as we found this quite difficult to code. We were able to overcome this challenge effectively, with our decision to look into other models and found that long-tailed distributions can also be a useful model. Throughout the completion of this project, the team has been very efficient in this online learning environment by regularly communicating with one another via zoom and messages.
#
# This project has greatly benefitted me by allowing me to gain extensive knowledge of complex systems and develop an understanding of how I can design and implement complex systems to address a problem effectively. However, I did face one significant challenge, which was that of my lack of experience and knowledge with coding. If I am faced with a real-world problem and need to do some modelling, I would determine which modelling approach to take by following a process very much like this project. I would ensure that I have a vast knowledge of the background of the problem and identify the limitations of prevailing models. I will identify alternative models that can resolve the issue, through the implementation process and then I will evaluate which model is the most effective. In the case where one model cannot wholistically resolve the problem, I will use many-mode thinking.

# %% [markdown]
# ### 7.4 Jimmy Wilkinson reflection

# %% [markdown]
# I found this assignment to be extremely interesting while challenging my research and coding skills. During the initial part, I helped complete sections 3.1, 3.2 and 3.3. This included explaining system dynamic models, how they work and what sorts of data sources would be useful for this assignment. I took many positives from this assignment, although many of them came after overcoming challenges. My coding skills were tested, although once I got the hang of the GitHub code I found it was much easier. Additionally, making sure that I fully understood how these models worked and how I would be able to use them to gain insightful outcomes took a while and I found it to be a bit of a struggle. It took me a while to find a code that I understood and felt comfortable using, but after looking at many different programs and codes I found one that worked well. If I was faced in a real-world situation and had to use modelling, I cannot say what model I would use. I’d need to know the context of what the issue is, and then apply my current understanding of the models I know to decide which may be most beneficial. Overall, I found this assignment quite challenging, but not impossible and learnt a lot about how to navigate real world issues through modelling.

# %% [markdown]
# # References

# %% [markdown]
#
# Alleman, P., & Rumble, L. (2020). *Gender equality during COVID-19.* UNICEF. https://www.unicef.org/rosa/stories/gender-equality-during-covid-19
#
# Alon, TM., Doepke, M., Olmstead-Rumsey, J. & Tertilt, M. (2020). The impact of COVID-19 on gender equality. *National Bureau of Economic Research working paper series*, 26947. https://www.nber.org/papers/w26947.pdf.
#
# AMP. (2020, May 29). Early super release providing critical support to women, but widening gender super gap. https://corporate.amp.com.au/newsroom/2020/MAY/early-super-release-gender-data
#
# Australian Institute of Criminology. (2020). *Prevalence of domestic violence experienced by respondents in the last three months* [infographic] https://www.aic.gov.au/sites/default/files/2020-07/sb28_prevalence_of_domestic_violence_among_women_during_covid-19_pandemic.pdf
#
# Australian Institute of Criminology. (2020). *The prevalence of domestic violence among women during the COVID-19 pandemic*. https://www.aic.gov.au/sites/default/files/2020-07/sb28_prevalence_of_domestic_violence_among_women_during_covid-19_pandemic.pdf
#
# Australian Taxation Office. (2020, September 16).
# *JobKeeper Payment: your eligible employees*. https://www.ato.gov.au/General/JobKeeper-Payment/Employers/Your-eligible-employees/
#
# Batchelor, R. (2020, August). The Impact of COVID-19 on Women and Work in Victoria. *The McKell Institute*.https://mckellinstitute.org.au/research/articles/the-impact-of-covid-19-on-women-and-work-in-victoria/
#
# Broomhill, R. & Sharp, R. (2005). The Changing Male Breadwinner Model in Australia: a New Gender Order?. *Labour & Industry: a journal of the social and economic relations of work*. 16. 103-127. 10.1080/10301763.2005.10722033
#
# Cassells, R. & Duncan, A. (2020). *Short term and long term casual workers: how different are they?* BankWest and Curtain University Economics Centre*. https://bcec.edu.au/assets/2020/04/BCEC-COVID19-Brief-4_Casual_Workers_FINAL.pdf
#
# Cerrato, J., & Cifre, E. (2018). Gender inequality in household chores and work-family conflict. *Frontiers in Psychology, 9*. https://doi.org/10.3389/fpsyg.2018.01330
#
# Colins College. (2017, March 25). Focus on Solving the Immediate Problems of Today. http://colinscollege.com/focus-on-solving-the-immediate-problems-of-today/
#
# Crabb, A. (2020, May 24). Coronavirus has left Australian women anxious, overworked, insecure — and worse off than men again. *ABC News*.https://www.abc.net.au/news/2020-05-24/coronavirus-has-set-back-progress-for-women-workplace-equality/12268742
#
# Doran M. (2020). “Domestic violence services prepare for demand as coronavirus restrictions begin to ease.” ABC News. www,abs.net.au/news/2020-05-01/domestic-violence-brace-for-demand-coronavirus-restrictions/12203178
#
# Fabrizio, S., Malta, V., Tavares, M. (2020). COVID-19: A backward step for gender equality. Covid Economics Vetted and Real-Time Papers. (49). https://voxeu.org/article/covid-19-backward-step-gender-equality
#
# Jenkins P, Philips B. (2008). “Battered women, catastrophe and the context of safety after Hurricane Katrina.” NWSA.
#
# John S. (2001). “System dynamics modelling: Tools for learning in a complex world”. California Management review, Vol 43, No 1.
#
# Karp, P. (2020, July 7). Australian women twice as likely as men to be 'discouraged workers' after Covid-19 job loss. *The Gaurdian*.https://www.theguardian.com/business/2020/jul/07/women-twice-as-likely-as-men-to-be-discouraged-workers-after-covid-19-job-loss
#
# Kelly F. (2020) “Google reports 75 percent spice in searched for help with domestic violence”. RN Breakfast. www.abc.net.au/radionational/programs/breakfast/reports-75-per-cent-spike-in-searches-for-help-with-domestic/12101690
#
#
# Madgavkar, A., White, W., Krishnan, M., Mahajan, D. & Azcue, X. (2020, July 15). *COVID-19 and gender equality: Countering the regressive effects. McKinsey & Company*. https://www.mckinsey.com/featured-insights/future-of-work/covid-19-and-gender-equality-countering-the-regressive-effects
#
# Mitchell, D. (n.d.). Reshaping Australian Social Policy: alternatives to the breadwinner welfare state. https://openresearch-repository.anu.edu.au/bitstream/1885/41754/3/MitchellDP55_PPP.pdf
#
# OECD. (2020, April 1). *Women at the core of the fight against COVID-19 crisis.*http://www.oecd.org/coronavirus/policy-responses/women-at-the-core-of-the-fight-against-covid-19-crisis-553a8269/
#
# Parliament of Australia. (2016). *Domestic violence and gender inequality*.https://www.aph.gov.au/Parliamentary_Business/Committees/Senate/Finance_and_Public_Administration/DVgenderinequality/Report/c02
#
# Parliament of Australia. (2020).*COVID19 - Impact On Women*. https://www.aph.gov.au/DocumentStore.ashx?id=6c48c9d0-e888-447c-bc77-54dbddf4af08
#
# Probyn, A. (2020, Jun 9). JobKeeper for childcare out, renovations in: Morrison's perplexing experiment turns the focus from women to men. *ABC News*.https://www.abc.net.au/news/2020-06-09/childcare-changes-to-disproportionately-affect-women/12333398
#
# Scheidel, W. (2017). *The great leveler : violence and the history of inequality from the Stone Age to the twenty-first century.* Princeton University Press.
#
# Stewart, E. (2020, July 10). The Federal Government's free childcare program ends on Monday. Here's what that means for you. *ABC News*.https://www.abc.net.au/news/2020-07-10/australian-government-free-childcare-to-end-explained/12438184
#
# The Power To Persuade. (2020, April 14). *Undervalued and unseen: Australia’s COVID-19 frontline workforce.* http://www.powertopersuade.org.au/blog/undervalued-and-unseen-australias-covid-19-frontline-workforce/14/4/2020
#
# Unicef Australia. (2020, May 5). *Coronavirus – a backward step for gender equality*. https://www.unicef.org.au/blog/news-and-insights/may-2020/coronavirus-gender
#
# United Nations. (2020, April 9). *The Impact of COVID-19 on Women*.https://www.un.org/sexualviolenceinconflict/wp-content/uploads/2020/06/report/policy-brief-the-impact-of-covid-19-on-women/policy-brief-the-impact-of-covid-19-on-women-en-1.pdf
#
# Wamera, E. (2020, March 29). *COVID-19: How gender stereotyping impacts delivery of sanitation and hygiene programmes*. Water Supply and Sanitation Collaborative Council. https://www.wsscc.org/media/news-stories/covid-19-how-gender-stereotyping-impacts-delivery-sanitation-and-hygiene
#
# WGEA. (2020, May 11). *Gendered Impact of COVID-19*. Workplace Gender Equality Agency. https://www.wgea.gov.au/topics/gendered-impact-of-covid-19
#
# Wood, D., Giffiths, K. & Emslie, O. (2020, April 27). Permanently raising the Child Care Subsidy is an economic opportunity too good to miss. *The Conversation*.https://theconversation.com/permanently-raising-the-child-care-subsidy-is-an-economic-opportunity-too-good-to-miss-136856
#
# Workplace Gender Equality Agency. (2020). *Gender workplace statistics at a glance 2020*.https://www.wgea.gov.au/data/fact-sheets/gender-workplace-statistics-at-a-glance-2020#:~:text=Educational%20Attainment,ABS%202019%2C%20Gender%20Indicators).
